# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image_as_array = mpimg.imread('nature.jpg')

# %%
image_as_array.shape  ####(H, W,C)
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(image_as_array)

# %%
(h,w,c) = image_as_array.shape

# %%
c
# Out:
# 3

# %%
image_as_array2d = image_as_array.reshape(h*w, c)

# %%
image_as_array2d
# Out:
# array([[47,  9, 46],
#        [48, 10, 47],
#        [51, 11, 48],
#        ...,
#        [ 6, 20,  5],
#        [ 0, 14,  0],
#        [ 0,  7,  0]], dtype=uint8)

# %%
len(image_as_array2d.shape)
# Out:
# 2

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
1080*1920
# Out:
# 2073600

# %%
labels
# Out:
# array([5, 5, 5, ..., 0, 0, 0])

# %%
model.cluster_centers_
# Out:
# array([[  8.99500585,  14.27487663,   4.1853703 ],
#        [226.87219397, 208.73230817, 221.90432884],
#        [130.41183616, 116.34427371,  73.8588575 ],
#        [188.78022211, 138.47779133, 169.32096239],
#        [137.60052419,  65.48466255, 140.61913235],
#        [ 64.83475397,  58.58779376,  32.99292678]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[  9,  14,   4],
#        [227, 209, 222],
#        [130, 116,  74],
#        [189, 138, 169],
#        [138,  65, 141],
#        [ 65,  59,  33]])

# %%
labels
# Out:
# array([5, 5, 5, ..., 0, 0, 0])

# %%
rgb_codes[labels]
# Out:
# array([[65, 59, 33],
#        [65, 59, 33],
#        [65, 59, 33],
#        ...,
#        [ 9, 14,  4],
#        [ 9, 14,  4],
#        [ 9, 14,  4]])

# %%
image_as_array2d
# Out:
# array([[47,  9, 46],
#        [48, 10, 47],
#        [51, 11, 48],
#        ...,
#        [ 6, 20,  5],
#        [ 0, 14,  0],
#        [ 0,  7,  0]], dtype=uint8)

# %%
quantized_image = np.reshape(rgb_codes[labels],(h,w,c))

# %%
plt.imshow(quantized_image)
